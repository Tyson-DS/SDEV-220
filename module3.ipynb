# %%
class Vehicle: 
    def __init__(self, vehicle_type): 
        self.vehicle_type = vehicle_type
        

class Automobile(Vehicle): 
    def __init__(self,vehicle_type, year, make, model, doors, roof):
        super().__init__(vehicle_type)
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof

vehicle_type = input("What Vehicle do you have: ")
year = int(input("What is the year of your car: "))
make = input("What is the make of your car: ")
model = input("What is the model of your car: ")
doors = int(input("how many doors does your car have: "))
roof = input("what type of roof does your car have: ")

user_car = Automobile(vehicle_type, year, make, model, doors, roof)

print("Vehicle type: ", user_car.vehicle_type,
      "\nYear: ", user_car.year,
      "\nMake: ", user_car.make,
      "\nModel: ", user_car.model, 
      "\nNumber of doors: ", user_car.doors, 
      "\nType of roof: ", user_car.roof)
# Out:
# What Vehicle do you have Car
# What is the year of your car:  2022
# What is the make of your car:  Toyota
# What is the model of your car:  Corolla
# how many doors does your car have:  4
# what type of roof does your car have:  moon roof
# Vehicle_type:  Car
# Year:  2022
# Make:  Toyota
# Model:  Corolla
# Number of doors:  4
# Type of roof:  moon roof
