# %%
#Tyson Steadman
#m2
#will prompt user for name and gpa and say if they made the deans list or the horrnor roll


Lname = input("Students lastname: ")
if Lname == "ZZZ" or Lname == "zzz":
    print("quitting...")
    quit()

Fname = input("stuendts firstname: ")
GPA = float(input("students gpa: "))

if GPA >= 3.25:
    if GPA >= 3.5:
        print("You made the honor roll and the deans list! amazing job!")
    else:
        print("you made the honor roll! good job!")
else:
    print("Maybe next time.")
# Out:
# Students lastname:  steadman
# stuendts firstname:  Tyson
# students gpa:  3.4
# you made the honor roll! good job!
